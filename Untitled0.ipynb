# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyen23012007/MY_PROJECT/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
ueh_coords = [10.761158591008995, 106.66836872262138]
m = folium.Map(location=ueh_coords, zoom_start=14)
folium.Marker(
    ueh_coords,
    popup="Đại học Kinh tế TP.HCM (UEH)",
    tooltip="Click để xem chi tiết",
    icon=folium.Icon(color='green', icon='university',prefix='fa')).add_to(m)
locations = [
    {"name": "Bệnh viện chợ rẫy", "coords": [10.758104537786622, 106.65977409629737], "type": "Bệnh Viện"},
    {"name": "Vạn Hạnh Mall", "coords": [10.770690727495419, 106.67011054841386], "type": "Trung tâm thương mại"},
    {"name": "Công Viên Hòa Bình", "coords": [10.760571857725472, 106.67369759167477], "type": "Công viên"}
]
for loc in locations:
    folium.Marker(
        loc["coords"],
        popup=f"{loc['name']} ({loc['type']})",
        icon=folium.Icon(color='blue')
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80541dce505e4930b86554b4c5488fb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80541dce505e4930b86554b4c5488fb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80541dce505e4930b86554b4c5488fb8 = L.map(
#                 &quot;map_80541dce505e4930b86554b4c5488fb8&quot;,
#                 {
#                     center: [10.761158591008995, 106.66836872262138],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91757eb698e1969c5bfa9c7139430ed7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91757eb698e1969c5bfa9c7139430ed7.addTo(map_80541dce505e4930b86554b4c5488fb8);
#
#
#             var marker_da4c9503ec2536b655f33f86e8ce128b = L.marker(
#                 [10.761158591008995, 106.66836872262138],
#                 {
# }
#             ).addTo(map_80541dce505e4930b86554b4c5488fb8);
#
#
#             var icon_e6d0d03f1eeebd200a00942fdc7515e8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4223822d13edae05a343af60a103a849 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81b6dc00f921a801e2668e94fa6d4ee4 = $(`&lt;div id=&quot;html_81b6dc00f921a801e2668e94fa6d4ee4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học Kinh tế TP.HCM (UEH)&lt;/div&gt;`)[0];
#                 popup_4223822d13edae05a343af60a103a849.setContent(html_81b6dc00f921a801e2668e94fa6d4ee4);
#
#
#
#         marker_da4c9503ec2536b655f33f86e8ce128b.bindPopup(popup_4223822d13edae05a343af60a103a849)
#         ;
#
#
#
#
#             marker_da4c9503ec2536b655f33f86e8ce128b.bindTooltip(
#                 `&lt;div&gt;
#                      Click để xem chi tiết
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_da4c9503ec2536b655f33f86e8ce128b.setIcon(icon_e6d0d03f1eeebd200a00942fdc7515e8);
#
#
#             var marker_9388c9d79f41be74311d7340680ef832 = L.marker(
#                 [10.758104537786622, 106.65977409629737],
#                 {
# }
#             ).addTo(map_80541dce505e4930b86554b4c5488fb8);
#
#
#             var icon_6d86d65c54584af35001710ff984577b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_eecb29d5fc21a4768e074ac1427b7c4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b9de9c75a5816f0d7f5f15521704983 = $(`&lt;div id=&quot;html_4b9de9c75a5816f0d7f5f15521704983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện chợ rẫy (Bệnh Viện)&lt;/div&gt;`)[0];
#                 popup_eecb29d5fc21a4768e074ac1427b7c4d.setContent(html_4b9de9c75a5816f0d7f5f15521704983);
#
#
#
#         marker_9388c9d79f41be74311d7340680ef832.bindPopup(popup_eecb29d5fc21a4768e074ac1427b7c4d)
#         ;
#
#
#
#
#                 marker_9388c9d79f41be74311d7340680ef832.setIcon(icon_6d86d65c54584af35001710ff984577b);
#
#
#             var marker_5444c20b2c10bfe7eedcac8b07146fe5 = L.marker(
#                 [10.770690727495419, 106.67011054841386],
#                 {
# }
#             ).addTo(map_80541dce505e4930b86554b4c5488fb8);
#
#
#             var icon_443ab9ad601b6f42fa73243c44557d09 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ccd5ec8556030ffc7d90e9716676b74d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f22b356d5781a16392959a53461244e = $(`&lt;div id=&quot;html_5f22b356d5781a16392959a53461244e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vạn Hạnh Mall (Trung tâm thương mại)&lt;/div&gt;`)[0];
#                 popup_ccd5ec8556030ffc7d90e9716676b74d.s
